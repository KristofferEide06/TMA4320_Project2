# %% [markdown]
# ### Forfattere:
# - Elias Veines-Jensen
# - Frederik Alexander Ådlandsvik
# - Kristoffer Eide
# - Samuel Vasshus

# %% [markdown]
# # Oppgave 1

# %% [markdown]
# ## a)
#
#
# Har differensialligningen
#
# $$
# \partial_t \,\phi (x,t) = D \,\partial_x^2 \,\phi (x,t), \hspace{5mm}, t \geq 0, x \in \mathbb{R}
# $$
#
# Anvender en fouriertransformasjonen på ligningen får en at,
#
# $$
# \partial_t \,\hat{\phi} (w,t) = D(iw)^2 \,\hat{\phi} (w,t) = -Dw^2 \,\hat{\phi} (w,t)
# $$
#
# som er en separabel differensialligning i frekvensrommet med løsning $\hspace{5mm} \hat{\phi} (w,t) = C(w) \,e^{-Dw^2 t}$
#
# $C(w)$ får en ved å angi en initialbetingelse $\phi (x,0) = h(x)$, hvilket medfører at $C(w) = \hat{h}(w)$.
#
# Videre kan en definere $\hat{g}(w, t) = e^{-Dw^2 t}$ med inverstransformasjonen $g(x, t) = \frac{1}{\sqrt{2Dt}} e^{-x^2/(4Dt)}$. Løsningen $\phi (x,t)$ blir en konvolusjon mellom $h(x)$ og $g(x, t)$:
#
# $$
# \displaystyle \phi (x,t) = \frac{1}{\sqrt{2\pi}} \left( h(x) * g(x, t) \right) = \frac{1}{\sqrt{2\pi}} \int_{-\infty}^{\infty} h(y) g(x-y, t) \,\mathrm{d}y = \frac{1}{\sqrt{4\pi Dt}} \int_{-\infty}^{\infty} h(y) e^{-(x-y)^2/(4Dt)} \,\mathrm{d}y
# $$

# %% [markdown]
# **Vi kan sjekke at løsningen våres stemmer:**
#
# $$
# \displaystyle \partial_t \phi \sim \partial_t \int_{-\infty}^{\infty} h(y)\,g(x-y,t) \,\mathrm{d}y = \int_{-\infty}^{\infty} h(y) \,\partial_t\,g(x-y, t) \,\mathrm{d}y
# $$
#
# Har at $\partial_t g(x, t) = D \,\partial_x^2 g(x,t)$, slik at
#
# $$
# \displaystyle \partial_t \phi \sim \int_{-\infty}^{\infty} h(y) D\,\partial_x^2\,g(x-y, t) \,\mathrm{d}y = D \partial_x^2 \int_{-\infty}^{\infty} h(y) \,g(x-y, t) \,\mathrm{d}y = D\,\partial_x^2 \,\phi
# $$
#
# Dette er under antagelsen at løsningen og de ulike deriverte konvergerer. Dermed har det som skulle vises blitt vist.

# %% [markdown]
# **Fysisk tolkning av h(y):**
#
# Fra utledningen av løsningen $\phi (x,t)$ fant vi at $h(y)$ var gitt som initialbetingelsen $\phi (x,0) = h(x)$. Dette kan også vises ved å ta grenseverdien når $t \rightarrow 0$:
#
# $$
# \int_{-\infty}^{\infty} g(x, t)\, \mathrm{d}x = \frac{1}{\sqrt{4\pi Dt}}
# \int_{-\infty}^{\infty} e^{-x^2/(4Dt)}\, \mathrm{d}x = 1 \quad \text{for alle } t > 0.
# $$
#
# En funksjon som smalner inn mot null men alltid har areal lik 1 konvergerer mot
# Dirac-deltaet, slik at $\lim_{t \rightarrow 0} g(x-y, t) = \delta(x - y)$,
# da følger det at
#
# $$
# \displaystyle \phi(x,0) = \int_{-\infty}^{\infty} h(y) \,\delta(x-y) \,\mathrm{d}y = h(x)
# $$
#
# $h(y)$, eller snarere $h(x)$, kan da tolkes som sannsynlighetstettheten til de ulike partikkelposisjonene ved start.

# %% [markdown]
# #### b)

# %% [markdown]
# $P(x)$ er overgangssannsynligheten for at en partikkel fra en vilkårlig posisjon beveger seg mot høyre, venstre eller står i ro. Denne avhenger kun av potensialforskjellen mellom nåværende posisjon og naboposisjoner.
#
# Dersom en modellerer dette med Boltzmann-statistikk får en at $\displaystyle P(x) = \frac{e^{-\beta V(x)}}{Z}$, der $\displaystyle \sum_{i=0}^{3} e^{-\beta V(x ^{(i)})} = e^{-\beta V(x_0 - 1)} + e^{-\beta V(x_0)} + e^{-\beta V(x_0 + 1)}$
#
#
# Dermed blir
#
# $$
# \displaystyle p^{-} = \frac{e^{-\beta V(x^{(i)})}}{Z} = \frac{e^{-\beta V(x_0 - 1)}}{e^{-\beta V(x_0 - 1)} + e^{-\beta V(x_0)} + e^{-\beta V(x_0 + 1)}} = \frac{1}{1 + e^{-\beta (V(x_0) - V(x_0-1))} + e^{-\beta (V(x_0+1) - V(x_0-1))}}
# $$
#
# $$
# \displaystyle p^{0} = \frac{e^{-\beta V(x^{(i)})}}{Z} = \frac{e^{-\beta V(x_0)}}{e^{-\beta V(x_0 - 1)} + e^{-\beta V(x_0)} + e^{-\beta V(x_0 + 1)}} = \frac{1}{1 + e^{-\beta (V(x_0-1) - V(x_0))} + e^{-\beta (V(x_0+1) - V(x_0))}}
# $$
#
# $$
# \displaystyle p^{+} = \frac{e^{-\beta V(x^{(i)})}}{Z} = \frac{e^{-\beta V(x_0+1)}}{e^{-\beta V(x_0 - 1)} + e^{-\beta V(x_0)} + e^{-\beta V(x_0 + 1)}} = \frac{1}{1 + e^{-\beta (V(x_0-1) - V(x_0+1))} + e^{-\beta (V(x_0) - V(x_0+1))}}
# $$

# %% [markdown]
# #### c)

# %% [markdown]
# Når temperaturen $T$ innfrir kravet $k_B T \gg |V(x+1)-V(x)|$ for en vilkårlig $x=x_0$ har en at
#
# $$
# -\beta |V(x_0) - V(x_0-1)| \rightarrow 0
# $$,
#
# $$
# -\beta |V(x_0+1) - V(x_0)| \rightarrow 0
# $$
#
# Følgelig må også
#
# $$
# -\beta |V(x_0+1) - V(x_0-1)| \rightarrow 0
# $$
#
# Dermed blir $\hspace{5mm} p^- \approx p^0 \approx p^+ \approx 1/3$.
#
# <br>
#
# Når temperaturen $T$ innfrir kravet $k_B T \ll |V(x+1)-V(x)|$ for en vilkårlig $x=x_0$ har en at når $V(x+1) > V(x) > V(x-1)$, er
#
# $$
# -\beta (V(x_0) - V(x_0-1)) \rightarrow -\infty \quad\text{og}\quad -\beta (V(x_0-1) - V(x_0)) \rightarrow \infty
# $$
#
# $$
# -\beta (V(x_0+1) - V(x_0)) \rightarrow -\infty \quad\text{og}\quad -\beta (V(x_0) - V(x_0+1)) \rightarrow \infty
# $$
#
# og følgelig må også
#
# $$
# -\beta (V(x_0+1) - V(x_0-1)) \rightarrow -\infty \quad\text{og}\quad -\beta (V(x_0-1) - V(x_0+1)) \rightarrow \infty
# $$
#
# Dermed blir $\hspace{5mm} p^- \approx 1 \hspace{2mm}$ og $\hspace{2mm} p^0 \approx p^+ \approx 0$.
#
# <br>
#
# Videre når $V(x+1) < V(x) < V(x-1)$ har en at
#
# $$
# -\beta (V(x_0) - V(x_0-1)) \rightarrow \infty \quad\text{og}\quad -\beta (V(x_0-1) - V(x_0)) \rightarrow -\infty
# $$
#
# $$
# -\beta (V(x_0+1) - V(x_0)) \rightarrow \infty \quad\text{og}\quad -\beta (V(x_0) - V(x_0+1)) \rightarrow -\infty
# $$
#
# og følgelig må også
#
# $$
# -\beta (V(x_0+1) - V(x_0-1)) \rightarrow \infty \quad\text{og}\quad -\beta (V(x_0-1) - V(x_0+1)) \rightarrow -\infty
# $$
#
# Dermed blir $\hspace{5mm} p^+ \approx 1 \hspace{2mm}$ og $\hspace{2mm} p^0 \approx p^- \approx 0$.
#
#
# <br>
#
# I tilfelle der det er et lokalt minima, dvs. $V(x) < V(x \pm 1)$, vil
#
# $$
# -\beta (V(x_0) - V(x_0-1)) \rightarrow \infty \quad\text{og}\quad -\beta (V(x_0-1) - V(x_0)) \rightarrow -\infty
# $$
#
# og
#
# $$
# -\beta (V(x_0+1) - V(x_0)) \rightarrow -\infty \quad\text{og}\quad -\beta (V(x_0) - V(x_0+1)) \rightarrow \infty
# $$
#
# Dermed blir $\hspace{5mm} p^0 \approx 1 \hspace{2mm}$ og $\hspace{2mm} p^+ \approx p^- \approx 0$.
#
#
# <br>
#
# Dersom punktet $x=x_0$ er et lokalt maksima, dvs. $V(x) > V(x \pm 1)$, vil
#
# $$
# -\beta (V(x_0-1) - V(x_0)) \rightarrow \infty \quad\text{og}\quad -\beta (V(x_0+1) - V(x_0)) \rightarrow \infty
# $$
#
# Dermed blir $p^0 \approx 0$, men det går ikke an å entydig bestemme hva $p^+$ og $p^-$ ettersom vi da må vite differansen $V(x+1) - V(x-1)$ er, som følger fra at
#
# $$
# \displaystyle \frac{p^+}{p^-} \approx e^{-\beta(V(x_0+1) - V(x_0-1))}
# $$.
#
# F.eks. vil tilfellet $V(x+1) = V(x-1)$ medføre at $p^+ \approx p^- \approx 1/2$.
#
#
# <br>
# <br>
#
# Vi kan simplifisere virrevandrings-problemet ved å tilnærmere sannsynligetene $p^-$, $p^0$ og $p^+$ med grensebetraktningene over når $\beta k \ll 1$ eller $\beta k\gg 1$.
#
# Ved høy temperatur ($k_B T \gg |V(x+1)-V(x)|$) er den termiske energien så mye større enn potensialforskjellene at potensialet er irrelevant, enhver overgang er lik sannsynlig. Vi kan sette $p^- \approx p^0 \approx p^+ \approx 1/3-$, Potensialet kan derfor ignoreres fullstendig i simuleringen.
#
# Ved lav temperatur ($k_B T \ll |V(x+1)-V(x)|$) vil potensialet dominere over den termiske energien. Partiklene beveger seg i stor grad med potensialgradienten og samler seg i de lokale minimumene, der de blir sittende ($p^0 \approx 1$). I simuleringen kan vi tilnærme problemet ved å fjerne den stokastiske virrevandringen og i stedet flytte partiklene deterministisk i retning av lavere potensial, og stå stille i et minimum.

# %% [markdown]
# ## Oppgave 2 a\)

# %% [markdown]
# #### Obs
#
# Når vi har i oppgavene $\beta k = 1$ eller $\beta k = 1000$, justerer vi bare størrelsene hver for seg i inputsene til funksjonene vi bruker slik at produktet blir riktig, e.g. $\beta = 1$ og $k = 1000$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from numba import njit
import matplotlib as mpl
from scipy.optimize import curve_fit

# %%
#Initial grid
binding_sites = np.zeros(501)

center = len(binding_sites)//2
half_span = 50 #101 particles = 2*50 + 1

binding_sites[center - half_span : center + half_span + 1] = 1

#Potential
@njit
def V1(x: int, k: float) -> float:
    """Constant potential

    Args:
        x: Position
        k: Potential strength (intercept)

    Returns:
        Potential value V1(x) = -k
    """
    return k

@njit
def V2(x: int, k: float) -> float:
    """Linear potential

    Args:
        x: Position
        k: Potential strength (slope) 
        
    Returns:
        Potential value V2(x) = - k*x
    """
    return -k*x

#Probability
@njit
def p(x0: int, V , beta: float, k: float) -> tuple[float, float]:
    """Probabliity of stepping to left or right from given position

    Args:
        x0: Current position
        V: Potential function V(x) that returns scalar potential value
        beta: Constant equal to 1/(Kb*T)
        k: Potential strength
        
    Returns:
        p_minus: Probablity of step to x0-1
        p_plus: Probablity of step to x0+1
    """
    
    p_minus = 1.0/(1.0 + np.exp(-beta*(V(x0 + 1, k) - V(x0 - 1, k))) + np.exp(-beta*(V(x0, k) - V(x0 - 1, k))))
    p_plus = 1.0/(1.0 + np.exp(-beta*(V(x0 - 1, k) - V(x0 + 1, k))) + np.exp(-beta*(V(x0, k) - V(x0 + 1, k))))
    
    return np.array([p_minus, p_plus])

# %%
#Walk simulation
@njit
def random_walk(initial_grid : np.ndarray, V, n_steps: int, beta : float, k : float) -> np.ndarray:
    """Simulates random walk without exclusion in given potential

    Args:
        initial_grid: Initial distribution of particles on binding sites
        V: Potential function V(x) that returns scalar potential value
        n_steps: Number of steps 
        beta: Physical parameter
        k: Potential physical paramater

    Returns: 
        grid: Updated grid with new particle positions 
    """
    grid = initial_grid.copy()
    n_sites = len(grid)
    
    for _ in range(n_steps):
        grid_new = np.zeros(n_sites)
        
        for i in range(n_sites):
            
            Nparticles = int(grid[i])
            
            if Nparticles == 0:
                continue
            
            for _ in range(Nparticles):
                p_minus, p_plus = p(i, V, beta, k)
                r = np.random.uniform(0.0, 1.0)
                
                if r < p_minus:
                    grid_new[i - 1] += 1
                elif r > 1 - p_plus:
                    grid_new[i + 1] += 1
                else:
                    grid_new[i] += 1
                    
        grid = grid_new
        
    return grid

#Several simulations and step
def sim_walk(initial_grid: np.ndarray, V, n_steps: int, n_sim: int, beta: float, k: float) -> tuple[np.ndarray, np.ndarray]:
    """Run n_sim random-walk simulations and return the x-grid and averaged distribution

    Args:
        initial_grid: Initial distribution of particles
        V: Potential function V(x) that returns svalar potential value 
        n_steps:  Number of steps
        n_sim: Number of simulations
        beta: Physical parameter
        k: Potential physical paramater

    Returns:
        x: Site coordinates centered around zero
        mean_grid: Mean final particle distribution across all runs
    """
    n_sites = len(initial_grid)
    
    grids = np.zeros((n_sim, n_sites))
    
    for i in range(n_sim):
        grid = random_walk(initial_grid, V, n_steps, beta, k)
        grids[i] = grid

    mean_grid = np.mean(grids, axis = 0)
    x = np.arange(n_sites) - n_sites//2
    
    return x, mean_grid

# %%
# Simulate walk for the two potentials
x_1, mean_grid_1 = sim_walk(binding_sites, V1, n_steps = 200, n_sim = 100, beta = 1.0, k = 1.0)
x_2, mean_grid_2 = sim_walk(binding_sites, V2, n_steps = 200, n_sim = 100, beta = 1.0, k = 1.0)

# Plot gaussian curve
def gaussian(x, A, mu, sigma):
    return A * np.exp(-(x - mu)**2 / (2 * sigma**2))


# Parameters for 2nd simulation
A0 = mean_grid_2.max()
mu0 = x_2[np.argmax(mean_grid_2)]
sigma0 = np.std(x_2) 

# Indexing with 1 is for the simulation with V1, and 2 is for the simulation with V2
params1, cov1 = curve_fit(gaussian, x_1, mean_grid_1)
params2, cov2 = curve_fit(gaussian, x_2, mean_grid_2, p0=[A0, mu0, sigma0])

A1, mu1, sigma1 = params1
y_fit1 = gaussian(x_1, A1, mu1, sigma1)

A2, mu2, sigma2 = params2
y_fit2 = gaussian(x_2, A2, mu2, sigma2)


fig, (ax1, ax2) = plt.subplots(2, 2, figsize=(12, 8))


ax1[0].plot(x_1, mean_grid_1, label="Average dist of particles")
ax1[0].grid()
ax1[1].plot(x_1, mean_grid_1, label="Average dist of particles")
ax1[1].plot(x_1, y_fit1, label="Best gaussian approx")
ax1[1].grid()

ax2[0].plot(x_2, mean_grid_2, label="Average dist of particles")
ax2[0].grid()
ax2[1].plot(x_2, mean_grid_2, label="Average dist of particles")
ax2[1].plot(x_2, y_fit2, label="Best gaussian approx")
ax2[1].grid()

ax1[0].set_title("Average dist of particles after 200 steps and 100 runs with V1")
ax1[1].set_title("Fit gaussian curve to walk simulation using V1")
ax2[0].set_title("Average dist of particles after 200 steps and 100 runs with V2")
ax2[1].set_title("Fit gaussian curve to walk simulation using V2")

ax1[1].legend()
ax2[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# I oppgave 2a er partikklene uavhengige og vi lar hver partikkel ta 200 steg. Fordelingen til enhver partikkel vil bli tilnærmet gaussisk fordelt i følge sentralgrenseteoremet. Dette er fordi hver partikkel tar 200 uavhengige steg med multinomisk sannsynlighet sannsynlighet for å gå til høyre eller venstre.
#
# Vi tar gjennomsnitt av partikkeltetthetene til alle partiklene, og tar dermed et gjennomsnitt av 101 partikkeltettheter som er tilnærmet gaussisk fordelte rundt sin startposisjon. Vi vet at summen av flere normalfordelte variabler med samme sentrum blir gaussisk fordelt, og det kunne dermed vært naturlig å forvente en normalfordeling, men i oppgaven starter partiklene på forskjellige posisjoner og dermed blir det ikke normalfordelt. Siden vi summerer flere normalfordelte partikler, der snittet av posisjonen til partiklene er om 0, kan det allikevel se litt slik ut. Vi bruker scipy til å undersøke fordelingen, og ser at det er klare avvik fra en normalfordeling, til tross for visse likheter, som stemmer med teorien.
#
# I det konstante potensialet er sannsynligheten for å gå til høyre elelr venstre lik og vi forventer at kurven er symmetrisk om sentru. Når potensialet blir linært synkende, blir sannynligheten for å gå mot høyre større enn sannsynlighet mot venstre, som fører til at fordelingen blir forskjøvet mot høyre. Dette stemmer med plottene.

# %% [markdown]
# ## Oppgave 2 b)

# %%
@njit
def random_walk_exclusion(initial_grid: np.ndarray, V, n_steps: int, beta: float, k: float) -> np.ndarray:
    """Simulates random walk without exclusion in given potential

    Args:
        initial_grid: Initial distribution of particles
        V: Potential function V(x) that returns scalar potential value 
        n_steps: Number of steps
        n_sim: Number of simulations
        beta: Constant equal to 1/(Kb*T)
        k: Potential strength
        
    Returns:
        Grid with particles particle positions (0/1)
    """
  
    occupancy = initial_grid.astype(np.bool_) 
    positions = np.where(occupancy)[0].copy() 
    
    for _ in range(n_steps):
        np.random.shuffle(positions)
        
        for idx in range(len(positions)):
            i = positions[idx]
            
            p_minus, p_plus = p(i, V, beta, k)
            r = np.random.uniform(0.0, 1.0)
                
            if r < p_minus:
                new_i = i-1
            elif r > 1 - p_plus:
                new_i = i + 1
            else:
                new_i = i
        
            if occupancy[new_i]:
                continue
            
            occupancy[i] = False
            occupancy[new_i] = True
            positions[idx] = new_i
            
    return occupancy.astype(np.int64)

def sim_walk_exclusion(initial_grid: np.ndarray, V, n_steps: int, n_sim: int, beta: float, k: float) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    """Run n_sim simulations with and without exclusion, plot both mean final distributions, and return x plus both averages

    Args:
        initial_grid: Initial distribution of particles
        V: Potential function V(x) that returns scalar potential value 
        n_steps: Number of steps
        n_sim: Number of simulations
        beta: Constant equal to 1/(Kb*T)
        k: Potential strength

    Returns:
        x: Site coordinates centered around zero
        mean_grid: Mean final distribution for non_exclusion
        mean_grid_exclusion: Mean final dsitribution for exclusion
    """
    n_sites = len(initial_grid)
    
    grids = np.zeros((n_sim, n_sites))
    grids_exclusion = np.zeros((n_sim, n_sites))
    
    for i in range(n_sim):
        grid = random_walk(initial_grid, V, n_steps, beta, k)
        grid_exclusion = random_walk_exclusion(initial_grid, V, n_steps, beta, k)
        grids[i] = grid
        grids_exclusion[i] = grid_exclusion

    mean_grid = np.mean(grids, axis = 0)
    mean_grid_exclusion = np.mean(grids_exclusion, axis = 0)
    x = np.arange(n_sites) - n_sites//2
        
    fig, ax = plt.subplots(figsize = (8, 4))
    
    ax.plot(x, mean_grid, label = "Non-exclusion")
    ax.plot(x, mean_grid_exclusion, label = "Exclusion")
    ax.set_xlabel("x")
    ax.set_ylabel("Average particle count")
    ax.set_title(f"Average dist of particles after {n_steps} steps and {n_sim} runs")
    ax.grid()
    plt.legend()
    plt.show()
    
    return x, mean_grid, mean_grid_exclusion

# %%
x_1, mean_grid, mean_grid_exclusion_1 = sim_walk_exclusion(binding_sites, V1, n_steps = 200, n_sim = 100, beta = 1.0, k = 1.0)
x_2, mean_grid, mean_grid_exclusion_2 = sim_walk_exclusion(binding_sites, V2, n_steps = 200, n_sim = 100, beta = 1.0, k = 1.0)

# Plot gausian curve
params, cov = curve_fit(gaussian, x_1, mean_grid_exclusion_1)

A, mu, sigma = params
y_fit = gaussian(x_1, A, mu, sigma)

plt.plot(x_1, mean_grid_exclusion_1, label="")
plt.plot(x_1, y_fit, label="Best gaussian aprox ")
plt.legend()
plt.show()

# %% [markdown]
# Nå er ikke partikklene uavhengige. Dette gjør at partikkler i midten ikke kan ha tetthet høyere enn 1. De sprer seg mer ut, noe vi ser på plottet for konstant potensial. Derfor blir det ikke nomalfoldelt, noe som vi også ser ut fra normalfordelingsplottet nederst.
#
# Men etterhvert partikklene sprer seg mer ut begynner overlapping å ha mindre å si, siden avstanden mellom partikklene øker, dermed ser vi på grafen for konstant potensial at fordeling med og uten kollisjon ser ganske like ut.
#
# Men når det blir tilført et potensial ser vi at dette påvirker ting mye mer. Partikklene kan ikke like lett gå mot høyre, siden dette fører til kollisjon. Så vi får mye mindre drift av partikkler. Partikklene til høyre må starte å dra mot hlyre, og så kan de partikklene litt mer til venstre begynne osv. Dermed får vi et plot som ser anderledes ut.

# %% [markdown]
# ## Oppgave 2 c)

# %%
x, mean_grid = sim_walk(binding_sites, V1, n_steps = 50, n_sim = 100, beta = 1.0, k = 1000.0)
x, mean_grid = sim_walk(binding_sites, V2, n_steps = 50, n_sim = 100, beta = 1.0, k = 1000.0)

x, mean_grid, mean_grid_exclusion = sim_walk_exclusion(binding_sites, V1, n_steps = 200, n_sim = 100, beta = 1.0, k = 1000.0)
x, mean_grid, mean_grid_exclusion = sim_walk_exclusion(binding_sites, V2, n_steps = 200, n_sim = 100, beta = 1.0, k = 1000.0)


#Sannsynlighet for steg til høyre reknet ut
sum_sannsynlighet_høyre = 0
for pos in x:
    sum_sannsynlighet_høyre += p(pos, V2, 1.0, 1000 )
avg = sum_sannsynlighet_høyre/(len(x))

print("Probability of step to right " + str(avg[1]))
# Out:
# Probability of step to right 1.0

# %% [markdown]
# **Konstant potensial**:
#
# Ettersom potensialdifferansen blir 0, har det ikke noe å si at $\beta k = 1000$ siden vi ganger med 0 og fortsatt får samme sannsynlighet $\frac 1 3$ for å gå til venstre og høyre. Derfor burde man forvente samme svar i 2a i og 2b i både med $\beta k = 1$ og $\beta k = 1000$ for plot 1 og 3 henholdsvis.
#
# **Linært potensial**:
#
# Når vi setter $\beta k = 1000$ I det lineære potensialet vil V(x+1) < V(x) < V(x-1), og når vi da setter $\beta k = 1000$ (ekvivalent med $k_B T << V(x+1) -V(x)$) kan vi ut fra resultatet av oppgave 1c konkludere med at sannsynligheten for at partiklene beveger seg mot høyre er tilnærmet lik 1.
#
# Dette ser vi tydelig i plot 2, der alle partiklene beveger seg uten kollisjon. Alle partiklene ender opp på linje uten mellomrom forskjøvet mot høyre. Dette gir mening siden alle partiklene startet ved siden av hverandre. For hvert steg beveger alle partiklene seg et steg mot høyre. Dermed ender alle partiklene 200 steg til høyre for der de startet.
#
# I det nederste plottet, når vi også har kollisjon ser vi fra plot 4 at mean grid får den oscillerende formen [0, 1, 0, 1, 0, 1...] der 0 symboliserer fraværet av partikkel og 1 tilstedeværelsen. Det er altså alltid et mellomrom mellom hver partikkel i plottet. Som et eksempel kan vi for enkelhets skyld illustrere stegene uten shuffling. Med startkonfigurasjonen av partikler 000111000, vil vi etter første simulasjon bare kunne bevege partikelen til høyre, og vi får 000110100. Neste steg vil de partiklene som har 0 til høyre for seg kunne bevege seg mot høyre og vi får 000101010. Når mellomrommene er skapt, kan de aldri fjernes igjen. Dette er siden sannsynlighet for å gå mot høyre, når vi har ledig plass til høyre, er tilnærmet lik 1.
#
# Men dette er hvis vi alltid starter med å bevege partikelen lengst til venstre. I realiteten flytter vi partiklene i tilfeldig rekkefølge. Vi må alstå shuffle rekkefølgen vi slytter partiklene slik at vi får tilfeldig bevegelse. Så ved bruk av shuffling kan partiklene før et steg ha fordelingen 000111000, og etter et steg ha fordelingen 00010110. dette skjer kun hvis vi er heldige å flytte partikkelen til høyre først. For da kan også partikkelen til ventre flytte seg til høyre i samme iterasjon. Men siden vi kjører 200 steg så er sannsynligheten for at vi alltid flytter partikkelen til høyre lik 0, så en eller annen gang vil vi flytte partikkelen til venstre først, og vi går f.eks fra 0001011000 til 00001010100, og skaper mellomrom. Begge to gir samme resultat, som vi ser i plot 4.

# %% [markdown]
# ## Oppgave 3 a)

# %%
def plotter(titles: np.ndarray, x_labels: np.ndarray, y_labels: np.ndarray, x_arrays: np.ndarray, y_arrays: np.ndarray, rows: int, cols: int, size: tuple[int, int] = (8,4), collective_title: str = "", labels: list[str] = None):
    """Plot multiple x/y datasets across one or more subplots

    Args:
        titles: Array of titles, one per subplot
        x_labels: Array of x axis labels, one per subplot
        y_labels: Array of y axis labels, one per subplot
        x_arrays: Array of x axis value arrays, one per graph
        y_arrays: Array of y axis value arrays, one per graph
        rows: Number of subplot rows
        cols: Number of subplot columns
        size: Figure size as (width, height) tuple
        collective_title: Optional title displayed above all subplots
        labels: Array of legend labels, one per graph

    Returns:
        None: Displays plot
    """
    
    fig, ax = plt.subplots(rows, cols, figsize=size)
    axes_flattened = ax.flatten() if rows*cols > 1 else [ax]
    
    # Making repeating axes array for plotting multiple graphs in one plot
    if len(axes_flattened) < len(x_arrays):
        graphs_per_plot = len(x_arrays) // len(axes_flattened)
        new_axes_list = []
        
        for ax in axes_flattened:
            for _ in range(graphs_per_plot):
                new_axes_list.append(ax)
                
        axes_flattened = np.array(new_axes_list)
        
    else:
        graphs_per_plot = 1
        
    # Simple plotting for every x_arrays[i] and y_arrays[i] pair.
    for i, ax in enumerate(axes_flattened):
        ax.plot(x_arrays[i], y_arrays[i],label=labels[i] if labels is not None else None)

        # If this is the first graph being plotted on this axis, indexing purpoes
        if i % graphs_per_plot == 0:
            ax.set_xlabel(x_labels[i//graphs_per_plot])
            ax.set_ylabel(y_labels[i//graphs_per_plot])
            ax.set_title(titles[i//graphs_per_plot])
            
        # If this is the last graph being plotted on this axis
        if i % graphs_per_plot == graphs_per_plot-1:
            ax.grid(True, alpha=0.3)
            
    if collective_title:
        fig.suptitle(collective_title)
    
    if labels is not None:
        plt.legend()
        
    fig.tight_layout()
    plt.show()

@njit
def walk_dir(p_minus: float, p_plus: float) -> int:
    """Choose a random walk direction based on left/right move probabilities

    Args:
        p_minus: Probability of a move to the left (minus)
        p_plus: Probability of a move to the right (plus)

    Returns:
        step: Integer step value (-1, 0, or 1)
    """
    rand_val = np.random.ranf()
    if rand_val <= p_minus:
        return -1
    elif rand_val >= (1 - p_plus):
        return 1
    else:
        return 0

@njit
def v31(x: int, Nx: int, alpha: float, k: float, beta: float) -> float:
    """Calculate the periodic potential V31 at position x

    Args:
        x: Position on x axis
        Nx: Length of intervall for periodic potential V31
        alpha: Position of potential switch within Nx, pos = Nxalpha
        k: Potential strength
        beta: Constant equal to 1/(Kb*T)

    Returns:
        v: Potential value at position x for V31
    """
    x_per = x % Nx
    if x_per < alpha * Nx:
        return k * x_per / (alpha * Nx )
    else:
        x_per = x_per - Nx
        return -k * x_per / ((1 - alpha) * Nx)


@njit
def v32(x: int, Nx: int, alpha: float, k: float, beta: float) -> float:
    """Calculate the periodic potential V32 at position x

    Args:
        x: Position on x axis
        Nx: Length of intervall for periodic potential V31
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Potential strength
        beta: Constant equal to 1/(Kb*T)

    Returns:
        V: Potential value at position x for V32
    """
    return 1.0


@njit
def probs_periodic(beta: float, x: int, Nx: int, alpha: float, k: float, t: int, Tp: int) -> tuple[float, float]:
    """Calculate the probabilities of all possible moves with the partition function

    Args:
        beta: Constant equal to 1/Kb*T
        x: Position on x axis
        Nx: Length of intervall for periodic potential V31
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Potential strength
        t: Timestep within [0, 2*Tp]
        Tp: Time period between potential switches V31/V32

    Returns:
        p_minus, p_plus: Probabilites for a move to the left (minus) and right (plus)
    """
    if -0.01/beta<(periodic_pot(t, Tp, x, Nx, alpha, k, beta) - periodic_pot(t, Tp, x + 1, Nx, alpha, k, beta))<0.01/beta:
        return 1/3,1/3
    b = -beta * (periodic_pot(t, Tp, x, Nx, alpha, k, beta) - periodic_pot(t, Tp, x + 1, Nx, alpha, k, beta))
    a = -beta * (periodic_pot(t, Tp, x - 1, Nx, alpha, k, beta) - periodic_pot(t, Tp, x + 1, Nx, alpha, k, beta))
    c = -beta * (periodic_pot(t, Tp, x + 1, Nx, alpha, k, beta) - periodic_pot(t, Tp, x - 1, Nx, alpha, k, beta))
    d = -beta * (periodic_pot(t, Tp, x, Nx, alpha, k, beta) - periodic_pot(t, Tp, x - 1, Nx, alpha, k, beta))

    #Cut off values to avoid overflow (reasonable approximation beacuse of large values)
    if a > 50:
        a = 50
    elif a < -50:
        a = -50
    if b > 50:
        b = 50
    elif b < -50:
        b = -50
    if c > 50:
        c = 50
    elif c < -50:
        c = -50
    if d > 50:
        d = 50
    elif d < -50:
        d = -50

    p_plus = 1.0 / (1.0 + np.exp(a) + np.exp(b))
    p_minus = 1.0 / (1.0 + np.exp(c) + np.exp(d))

    return p_minus, p_plus

@njit
def periodic_pot(t: int, Tp: int, x: int, Nx: int, alpha: float, k: float, beta: float) -> float():
    """Select the periodic potential based on the current time step

    Args:
        t: Timestep witin [0,2*Tp]
        Tp: Time period between potential switches V31/V32
        x: Position on x axis
        Nx: Length of intervall for periodic potential V31
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Potential strength
        beta: Constant equal to 1/Kb*T

    Returns:
        V: Potential value at position x for the active potential (V31 or V32)
    """
    if t % (2 * Tp) < Tp:
        return v32(x, Nx, alpha, k, beta)
    else:
        return v31(x, Nx, alpha, k, beta)


@njit
def walk_step(Nx: int, alpha: float, k: float, Np: int, t: int, Tp: int, x: np.ndarray, interval: int, beta: float) -> tuple[np.ndarray, float]:
    """Perform one timestep of the random walk for all particles

    Args:
        Nx: Length of intervall for periodic potential V31
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Ootential strength
        Np: Number of particles
        t: Timestep witin [0,2*Tp]
        Tp: Time period between potential switches V31/V32
        x: Array of particle positions
        interval: Length of position interval (wrap-around boundary)
        beta: Constant equal to 1/Kb*T

    Returns:
        x: Updated array of particle positions after one timestep
        flow: Normalized net flow (Nplus - n_minus) / Np for this timestep
    """

    Nplus = 0
    n_minus = 0
    # Finding and performing steps for all the particles
    for j in range(len(x)):
        p_minus, p_plus = probs_periodic(beta, x[j], Nx, alpha, k, t, Tp)
        step = walk_dir(p_minus, p_plus)

        if step == 1:
            Nplus += 1
            if x[j] == (interval-1):
                x[j] = 0
            else:
                x[j] += step
        elif step == -1:
            n_minus += 1
            if x[j] == 0:
                x[j] = interval-1
            else:
                x[j] += step

    flow = (Nplus - n_minus) / Np
    return x, flow


def sim3_a(Tp: int, Nx: int, alpha: float, k: float, Np: int, cycles: int, interval: int, beta: float) -> tuple[np.ndarray, np.ndarray]:
    """Simulate the random walk with a switching periodic potential over multiple cycles

    Args:
        Tp: Time period between potential switches V31/V32
        Nx: Length of intervall for periodic potential V31
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Konstant for potential strength
        Np: Number of particles
        cycles: Number of full cycles to simulate
        interval: Length of position interval (wrap-around boundary)
        beta: Constant equal to 1/Kb*T

    Returns:
        x: Final array of particle positions after all cycles
        avg_flow: Array of average flow per cycle
    """
    # Creating array with Np elements (positions) in range [0,interval),
    # where there are Np//interval repetitions of each position
    x = np.array([[i for _ in range((Np // interval))] for i in range(interval)]).flatten()
    avg_flow = np.zeros(cycles)

    # Going through all periods Tp for all cycles and adding their J_avg to the avg_flow array
    for cycle in range(cycles):
        flow_t = np.zeros(2 * Tp)
        for t in range(2 * Tp):
            x, flow = walk_step(Nx, alpha, k, Np, t, Tp, x, interval, beta)
            flow_t[t] = flow
        avg_flow[cycle] = np.mean(flow_t)

    return x, avg_flow


x_10, avg_flow_08 = sim3_a(Tp=500, Nx=100, alpha=0.8, k=1000, Np=1200, cycles=10, interval=200, beta=1.0)
x_10, avg_flow_01 = sim3_a(Tp=500, Nx=100, alpha=0.1, k=1000, Np=1200, cycles=10, interval=200, beta=1.0)

# %%
print(avg_flow_08)
print(avg_flow_01)
# Out:
# [-0.03058333 -0.01308333 -0.01233333 -0.0135     -0.01358333 -0.01341667
#  -0.0155     -0.012      -0.01283333 -0.01316667]
# [0.0385     0.02875    0.02866667 0.02825    0.02716667 0.02758333
#  0.02975    0.02775    0.03       0.02725   ]

# %% [markdown]
# ### i)
# Vi får ikke-null partikkelstrømmer fordi potensial 1 har en positiv derivert for 80% av det periodiske intervallet, mot de 20%ene som er dekt av den negative deriverte. Dette vil si at hvis partiklene er uniformt fordelte vil 80% av de ha størst sjanse til å gå mot venstre, fordi dette er "nedover potensialgrafen" for de, mens resten vil ha størst sjanse for å gå mot høyre. I praksis vil denne sjansen for å gå mot høyre eller venstre være 100% da potensialstyrken er veldig stor i dette eksempelet, noe som fører til at vi får netto forflytning mot venstre, også kjent som negativ gjennomsnittlig partikkelflyt ($J_{avg}$). Enda en ting som gjør at denne strømningen blir betydelig forskjellig fra null, og ikke skalerer linært med alpha er at når alpha blir veldig liten eller veldig stor er det ikke bare flere partikler som beveger seg samme vei, men de nært toppunktet ($\alpha$) beveger seg også lengre, slik at flyten blir proposjonal med $c * \alpha^2$.
#
# Fysiskt kan dette forklares ved å tenke på partiklene som kuler som ligger oppå potensialgrafen, Disse kulene vil da rulle mot deres lokale minimum for potensial energi, og vil da med andre ord forflytte seg mot venstre for 80% av hver periode, og mot venstre for de andre 20%ene. hvis vi da legger sammen den distansen alle kulene har bevegd seg, mens vi tar hensyn til fortegn på bevegelsen, vil vi se at denne blir negativ. Vi har valgt å plotte potensial 1 med $\alpha = 0.8$ under for å illustrere potensialgrafen.

# %%
x_vals = np.arange(0, 20.0001)
v_vals = np.array([v31(x=x, Nx=10, alpha=0.8, k=1000, beta=1.0) for x in x_vals])

plotter(
    np.array([r"V31 over two intervals, $\alpha = 0.8$"]),
    np.array([r"$x$"]),
    np.array([r"$V_{31}(x)$"]),
    np.array([x_vals]),
    np.array([v_vals]),
    1, 1
)

# %% [markdown]
# ### ii)
# Vi ser at den første målingen av $J_{avg}$ er betydelig større enn alle de andre målingene som er relatvit like. Dette an forklares ved at partiklene orginalt er jevt fordelt for å så bevege seg slik at de i praksis alle er ved minimalt potensial under potensial 1, deretter byttes potensialet til potensial 2 som er konstant, og fører til tilfeldig bevegelse, på grunn av at denne tilfeldige bevegelsen skjer i en begrenset tidsperiode, og at partiklene i utgangspunktet alle er veldig nær posisjon 0, forventer vi at de er betydelig nærmere posisjon 0 enn når de var jevnt fordelte ved tidspunktet der vi bytter tilbake til potensial 1. Dette gjør at vi får mindre bevegelse og derfor en lavere $J_{avg}$.
#
#
# ### iii)
# Her ser vi at $J_{avg}$ er mot høyre isteden for venstre (positiv isteden for negativ) som vi forventer da potensial 1 nå har mye større del med negativ derivert enn positiv derivert.

# %% [markdown]
# Oppgave 3 b)

# %%
@njit
def sim3_ab(Tp: int, Nx: int, alpha: float, k: float,
           Np: int, pos1: int, pos2: int, interval: int, beta: float) -> tuple[np.ndarray, float]:
    """Simulate the random walk with a switching periodic potential for two particle groups

    Args:
        Tp: Time period between potential switches V31/V32
        Nx: Length of intervall for periodic potential V31
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Potential strength
        Np: Number of particles
        pos1: Initial position of the first group of particles
        pos2: Initial position of the second group of particles
        interval: Length of position interval (wrap-around boundary)
        beta: Constant equal to 1/(Kb*T)

    Returns:
        x: Final array of particle positions after one cycle
        avg_flow: Average flow over one full cycle
    """
    # Making an array of particles equally divided between position 1 and 2
    x = np.array([[pos1 for _ in range(Np // 2)],
                  [pos2 for _ in range(Np // 2)]]).flatten()

    flow_t = np.zeros(2 * Tp)

    for t in range(2 * Tp):
        x, flow = walk_step(Nx, alpha, k, Np, t, Tp, x, interval, beta)
        flow_t[t] = flow
    avg_flow = np.mean(flow_t)

    return x, avg_flow

# Initializing Tp array with 50 evenly spaced Tp values and empty flow array with same length of type np.float64
Tp_array = np.int64(np.linspace(1, 1001, 50))
flow_array_3b = np.zeros(len(Tp_array), dtype=np.float64)

# Simulating the J_avg for all values of Tp and adding them to flow array for plotting
for i in range(len(Tp_array)):
    x, avg_flow_3b = sim3_ab(Tp=Tp_array[i], Nx=100, alpha=0.8,k=1000,
                            Np=40 * 100, pos1=0, pos2=100, interval=200, beta=1.0)
    flow_array_3b[i] = avg_flow_3b

plotter(titles=np.array(["Average particle flow as a function of time period length"]),
        x_labels=np.array([r"$Tp$"]), y_labels=np.array([r"$J_{\mathrm{avg}}$"]),
        x_arrays=np.array([Tp_array]), y_arrays=np.array([flow_array_3b]), rows=1, cols=1)

# %% [markdown]
# Vi observer at magnituden til $J_{avg}$ starter rundt null, for å så gå opp til et maksimum ved $Tp \in [350, 550]$, magnituden av flyten minker etter dette. En tolkning av den initielle økningen i magnitude er at partiklene trenger noe tid for å spre seg utover mens potensial 2 er aktivt for at vi skal se noe utslag i $J_{avg}$. Dette kan forklares ved at partiklene vil gå veldig lite vekk fra minimum i potensial 1 ved et lavt antall tidssteg som fører til at veien tilbake til minimum er like lang uavhengig av hvilken vei de gikk da asymmetrien i potensialet i prakisis "ikke oppdages" av partiklene, dette gjør da at $J_{avg}$ blir null.
#
# For å forklare hvorfor magnituden igjen går ned ved en tilstrekkelig høy verdi for $Tp$, kan vi se på formelen for å regne ut $J_{avg}$. Vi har tenkt oss at denne er i noen grad porposjonal med hvor langt partiklene er unna minimumet i potensial 1, dette vil i vårt tilfelle makismeres når partiklene er uniformt fordelt, når vi ser bort fra ekstremt usannsynlige tilfeller. Videre vet vi at $J_{avg}$ er lineært omvendtproposjonalt med Tp, mens den gjennomsnittlige avstanden fra en partikkel til minimum i potensial 1 er ikke-linært proposjonal $Tp$, Vi ser en stor effekt av økning i $Tp$ i starten, som minker etterhvert som $Tp$ øker. Dette gjør at vi vil får en kamp mellom det positive bidraget til magnituden av flyten fra $Tp$ som har en negativ derivert, og det negative bidraget fra $Tp$ som har en konstant derivert, gitt at det positive bidraget starter større enn det negative må vi da finne et eller annet punkt $T_{p_{maks}} > T_{p_0}$ der magnituden av $J_{avg}$ maksimeres.

# %% [markdown]
# ## Oppgave 3 c)

# %%
import math as math

def analytic_flow(Nx: int, Tp: int, alpha: float) -> float:
    """Calculate the analytical average particle flow as a function of alpha, Nx and Tp

    Args:
        Nx: Length of intervall for periodic potential V31
        Tp: Time period between potential switches V31/V32
        alpha: Position of potential switch within Nx, pos = Nx*alpha

    Returns:
        flow: Analytical average particle flow for the given parameters
    """
    return Nx/(4*Tp) * (
        math.erfc(alpha*Nx/2*np.sqrt(3/Tp))
        - math.erfc((1-alpha)*Nx/2*np.sqrt(3/Tp))
    )

# Initializing alpha array with 50 evenly spaced Tp values and empty flow arrays with same length of type np.float64
alpha_array = np.linspace(0, 1, 50)
flow_array_3c = np.zeros(len(alpha_array), dtype=np.float64)
analytic_flow_array_3c = np.zeros(len(alpha_array), dtype=np.float64)

# Simulating the J_avg for all values of alpha and adding them to flow arrays for plotting
for i in range(len(alpha_array)):
    x, avg_flow = sim3_ab(Tp=500, Nx=100, alpha=alpha_array[i], k=1000, Np=40*100,
                        pos1=0, pos2=100, interval=200, beta=1.0)
    flow_array_3c[i] = avg_flow
    analytic_flow_array_3c[i] = analytic_flow(Nx=100, Tp=500, alpha=alpha_array[i])

plotter(titles=np.array(["Average particle flow as a function of alpha, nummerical versus analytical"]),
        x_labels=np.array([r"$\alpha$"]), y_labels=np.array([r"$J_{\mathrm{avg}}$"]),
        x_arrays=np.array([alpha_array for _ in range(2)]), 
        y_arrays=np.array([flow_array_3c,analytic_flow_array_3c]),
        rows=1, cols=1, labels=np.array(["Nummerical","Analytical"]))

# %% [markdown]
# Den nummeriske løsningen vår er veldig lik den analytiske løsningen som tyder på at oppgaven er løst rett. Vi ser en korrelasjon mellom $|\alpha-0.5|$ og magnituden av $J_{avg}$, vi kan se at magnituden av den andre deriverte av funksjonen når maks rundt $\alpha = 0.75$ og $\alpha = 0.25$.

# %% [markdown]
# ## Oppgave 3 d)

# %%
k_array = np.array([0.01, 1, 2, 3, 5, 10])
flow_array_list = []

for k in k_array:
    # Initializing alpha array with 50 evenly spaced alpha values and empty flow arrays with same length of type np.float64
    alpha_array = np.linspace(0, 1, 50)
    flow_array_3d = np.zeros(len(alpha_array), dtype=np.float64)
    analytic_flow_array_3d = np.zeros(len(alpha_array), dtype=np.float64)

    # Simulating the J_avg for all values of alpha and adding them to a list of flow arrays for plotting
    for i in range(len(alpha_array)):
        x, avg_flow = sim3_ab(Tp=500, Nx=100, alpha=alpha_array[i], k=k, Np=40*100,
                            pos1=0, pos2=100, interval=200, beta=1.0)
        flow_array_3d[i] = avg_flow
        analytic_flow_array_3d[i] = analytic_flow(Nx=100, Tp=500, alpha=alpha_array[i])
    flow_array_list.append(flow_array_3d)
    flow_array_list.append(analytic_flow_array_3d)
flow_arrays = np.array(flow_array_list)

title_array = np.array([rf"$k = {k}$" for k in k_array])

plotter(titles=title_array, x_labels=np.array([r"$\alpha$" for _ in range(len(k_array))]),
        y_labels=np.array([r"$J_{\mathrm{avg}}$" for _ in range(len(k_array))]),
        x_arrays=np.array([alpha_array for _ in range(len(k_array)*2)]),
        y_arrays=flow_arrays, rows=3, cols=2, size=(10,8),
        collective_title="Average particle flow as a function of alpha, nummerical versus analytical at different k-values",
        labels=np.array([["Nummerical","Analytical"] for _ in range(len(k_array))]).flatten())

# %% [markdown]
# ## Oppgave 3 e)

# %%
# Initializing Tp array with 20 evenly spaced Tp values and empty flow array with same length of type np.float64
Tp_array = np.int64(np.linspace(80, 1500, 50))
flow_array_3e = np.zeros(len(Tp_array), dtype=np.float64)
analytic_flow_array_3e = np.zeros(len(Tp_array), dtype=np.float64)

# Simulating the J_avg for all values of Tp and adding them to flow array for plotting
for i in range(len(Tp_array)):
    x, avg_flow_3e = sim3_ab(Tp=Tp_array[i], Nx=10, alpha=0.8, k=1000,
                            Np=40 * 10, pos1=0, pos2=10, interval=20, beta=1.0)
    flow_array_3e[i] = avg_flow_3e
    analytic_flow_array_3e[i] = analytic_flow(Nx=10, Tp=Tp_array[i], alpha=0.8)

plotter(titles=np.array(["Average particle flow as a function of time period length, nummerical vs analytical"]),
        x_labels=np.array([r"$Tp$"]), y_labels=np.array([r"$J_{\mathrm{avg}}$"]),
        x_arrays=np.array([Tp_array for _ in range(2)]), 
        y_arrays=np.array([flow_array_3e,analytic_flow_array_3e]),
        rows=1, cols=1,labels=np.array(["Nummerical","Analytical"]))

# %% [markdown]
# Grafene er lingende, forskjeller er diskutert i del f.

# %% [markdown]
# ## Oppgave 3 f)

# %% [markdown]
# Resultatene fra 3d viser at den analytiske løsningen er svært unøyaktig for svakere potensialer. Dette kan forklares ved å se på anntakelsene den analytiske løsningnen bruker, løsningen antar at partiklene beveger seg mot det lokale potensial minimumet, noe som kun skjer i praksis når potensialet og tidsperioden er tilstrekkelig store. En betydelig begrensning av den analytiske løsningen er derfor behovet for sterke potensialer.
#
# resultatene fra 3e viser at den analytiske løsningen antar at magnituden til $J_{avg}$ går mot null noe fortere enn den nummeriske løsningen viser. Dette foresakes trolig av en rekke forenklinger, 1. anntakelse om at alle partiklene når lokalt minimum i løpet av perioden der "sag-potensialet" er aktivt, 2. anntakelsen om like startbetingelser på for hver syklus, 3. anntakelsen om at partikler alltid går den veien de har størst sannynlighet for å gå. Det er også mulig bruk av kontinuerlige poisjoner i den analytiske løsningen mot diskrete posisjoner i den nummeriske løsningen har en innvirkning, spesielt med tanke på at $Nx$ er veldig liten i 3e, og at potensial forksjellen mellom to posisjoner derfor blir veldig stor.

# %% [markdown]
# ## Oppgave 4a\)

# %%
@njit
def build_initial(width: int, partition: int, 
                  Nx: int, Ns: int, Np: int = -1) -> np.ndarray:
    """Build an initial grid with particles spread out around the center
    
    Args:
        width: Total width of particles
        partition: How much of grid should be particle-covered
        Nx: Sites per sawtooth period
        Ns: Number of sawtooth periods
        Np: Number of particles to place. Default Np = -1 computes from partition. 
        
    Returns:
        initial_grid : 1D array (0/1) of length Ns*Nx where 1 symbolizes occupied site
    """
    binding_sites = np.zeros(Ns*Nx)
    center = len(binding_sites)//2
    initial_grid = binding_sites.copy()
    
    Npossible = len(binding_sites)//width
    if Np == -1:
        Np = Npossible//partition
    if Np <= 0:
        return initial_grid
    elif Np > Npossible:
        Np = Npossible
        
    initial_grid[center] = 1
    half = (Np - 1)//2
    
    #Spread particles around middle
    for n in range(1, half + 1):
        initial_grid[(center - n*width)%len(binding_sites)] = 1
        initial_grid[(center + n*width)%len(binding_sites)] = 1
    
    if Np%2 == 0: #To get equal particles around center if even
        initial_grid[(center + (half + 1) * width) % len(binding_sites)] = 1
    
    return initial_grid

@njit
def active_potential(t: int, Tp: int) -> int:
    """Calculates which potential is active during certain time

    Args:
        t: Time
        Tp: Time period between potential switches V31/V32

    Returns:
        0 for potential V32, 1 for potential V31
    """
    if (t // Tp) % 2 == 0:
        return 0
    else:
        return 1 
    
#Random walk
@njit
def random_walk_exclusion_sawtooth(initial_grid: np.ndarray, 
                                   Tp: int, 
                                   width: int, 
                                   Nx: int, Ns: int, Nc: int,
                                   alpha: float, k: float, beta: float,
                                   h: int, store_positions:bool = True, store_anim:bool = False) -> tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    """Simulates random walk with exclusion principle in rachet potential

    Args:
        initial_grid: Initial distribution of particles (0/1)
        Tp : Half-period of potential-switching
        width: Total width of particles
        Nx: Sites per sawtooth period
        Ns: Number of sawtooth periods
        Nc: Number of full cycles
        alpha: Potential physical parameter
        k: Potential strength
        beta: Constant 1/(Kb*T)
        h: Time-step size
        store_positions: Defaults to True. If True, store particle positions for each time step
        store_anim: Defaults to False. If True, store snapshots of positions and phaase_arr with potential for each time_step. 

    Returns:
        occupancy: Array(True/False) describing particle locations in final grid
        cycle_avg_J: Cycle-averaged current 
        positions_arr: Stores positions (T, Np) for each time step if enabled, else (1,1) zero-array
        snapshots: Stores positions (n_frames, Np) for each frame and particle if enabled, else (1, 1) zero-array
        phase: Stores active potential (n_frames) for each frame if enabled, else (1) zerro_array
    """
    #
    T = 2*Nc*Tp
    
    occupancy = initial_grid.astype(np.bool_)
    positions = np.where(occupancy)[0].copy()
    J_arr = np.zeros(T)
    
    Np = len(positions)
    order = np.arange(Np)
    
    #Initalize positions arr
    if store_positions:
        positions_arr = np.zeros((T, Np), dtype=np.int64)
    else:
        positions_arr = np.zeros((1, 1), dtype=np.int64)
        
    #Initialize animations arr
    if store_anim:
        n_time_steps = len(range(0, T, h))
        n_frames = 1 + n_time_steps*Np
        frame_idx = 0
        
        snapshots = np.zeros((n_frames, Np), dtype = np.int64)
        phase = np.zeros((n_frames), dtype = np.int64)
        
        snapshots[frame_idx] = positions
        phase[frame_idx] = active_potential(0, Tp)
    else:
        snapshots = np.zeros((1, 1), dtype=np.int64)
        phase = np.zeros(1, dtype=np.int64)
            
    for t in range(0, T, h):
        nplus = 0
        nminus = 0
        np.random.shuffle(order)    
        
        for n in range(Np):
            idx = order[n]
            i = positions[idx]
            
            p_minus, p_plus = probs_periodic(beta, i, Nx, alpha, k , t, Tp)
            
            step = walk_dir(p_minus, p_plus)
            new_i = (i + step)%(Ns*Nx)

            #Check for blocks with respect to width
            check_left = np.arange(new_i - width + 1, new_i +1)%len(occupancy)
            check_right = np.arange(new_i , new_i + width)%len(occupancy)
            
            blocked = (new_i == (i + 1) % (Ns*Nx) and occupancy[check_right].any()) or (new_i == (i - 1) % (Ns*Nx) and occupancy[check_left].any())
            
            if not blocked:
                occupancy[i] = False
                occupancy[new_i] = True
                positions[idx] = new_i
            
                if new_i == (i + 1) % (Ns*Nx): 
                    nplus += 1
                elif new_i == (i - 1) % (Ns*Nx): 
                    nminus += 1
                
            if store_anim:
                frame_idx += 1
                snapshots[frame_idx] = positions 
                phase[frame_idx] = active_potential(t, Tp)
                
        J_arr[t] = (nplus - nminus)/Np
        
        if store_positions:
            positions_arr[t] = positions
            
    n_cycles = len(J_arr)//(2*Tp)       
    J_reshaped = J_arr.reshape(n_cycles, 2*Tp) #Creates matrix where each row is one cycle
    cycle_avg_J = np.zeros(n_cycles)
    
    for c in range(n_cycles):
        cycle_avg_J[c] = J_reshaped[c].mean()
        
    return occupancy.astype(np.int64), cycle_avg_J, positions_arr, snapshots, phase

# %%
def plot_walk_exclusion_sawtooth(Tp: int, 
                                 width: int, 
                                 Nx: int, Ns: int, Nc: int, 
                                 alpha: float, beta: float, k: float,
                                 Np: int = -1, 
                                 h: int = 1) -> None:
    """Plots the time evolution of particle positions in random walk in ratchet potential with exclusion principle

    Args:
        Tp : Half-period of potential-switching
        width: Total width of particles
        Nx: Sites per sawtooth period
        Ns: Number of sawtooth periods
        Nc: Number of full cycles
        alpha: Potential physical parameter
        k: Potential strength
        beta: Constant equal to 1/(Kb*T)
        Np: Number of particles. Defaults to -1.
        h: Time-step size. Defaults to 1. 

    Returns:
        None: Displays the plot
    """
    initial_grid = build_initial(width, 2, Nx, Ns, Np)
    grid, cycle_av_J, positions_arr, snapshots, phase = random_walk_exclusion_sawtooth(initial_grid, Tp, width, Nx, Ns, Nc, alpha, k, beta, h)
    
    fig, ax = plt.subplots(figsize = (8, 4))
    
    time = np.arange(len(positions_arr))

    #Particle movement plot
    for p in range(positions_arr.shape[1]):
        ax.plot(time, positions_arr[:, p])
        
    #Periodic potential plot
    T = len(positions_arr)
    for t0 in range(0, T, 2*Tp):
        t1 = t0 + Tp
        t2 = t0 + 2*Tp
        
        ax.axvspan(t0, t1, color="tab:blue", alpha=0.10,
               label="V32" if t0 == 0 else None, zorder=0)
        ax.axvspan(t1, t2, color="tab:orange", alpha=0.10,
               label="V31" if t0 == 0 else None, zorder=0)
          
    ax.set_title("Time development of particle positions in ratchet potential with exclusion principle")
    ax.set_xlabel("Time step")
    ax.set_ylabel("Grid index")  
    ax.grid()  
    ax.legend(loc = "upper right")

    plt.show()

    return None

def animate_random_walk_exclusion(Tp: int, 
                                 width: int, 
                                 Nx: int, Ns: int, Nc: int, 
                                 alpha: float, beta: float, k: float,
                                 Np: int = -1, 
                                 h: int = 1,
                                 interval: int = 40) -> None:
    """Animate exclusion random walk in ratchet potential with exclusion principle
    
    Args:
        Tp : Half-period of potential-switching
        width: Total width of particles
        Nx: Sites per sawtooth period
        Ns: Number of sawtooth periods
        Nc: Number of full cycles
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Potential strength
        beta: Constant equal to 1/(Kb*T)
        Np: Number of particles. Defaults to -1.
        h: Time-step size. Defaults to 1. 
        interval: Delay between animation frames in milliseconds
    
    Returns:
        None: Displays the animation
    """
    
    initial_grid = build_initial(width, 2, Nx, Ns, Np)
    grid, cycle_av_J, positions_arr, snapshots, phase = random_walk_exclusion_sawtooth(initial_grid, Tp, width, Nx, Ns, Nc, alpha, k, beta, h, store_positions = False, store_anim = True)
    
    n_frames = snapshots.shape[0]
    Nparticles = snapshots.shape[1]
    L = Ns*Nx
    
    fig, ax = plt.subplots(figsize = (8, 4)) 
    mpl.rcParams["animation.embed_limit"] = 100 #Increase animation cap
    ax.set_xlim(-0.5, L - 0.5)
    ax.set_ylim(-1, 1)
    ax.set_yticks([])
    ax.set_xlabel("Grid index")
    ax.set_title("Time development of particle position in ratchet potential with exclusion principle")
    
    colors = plt.cm.tab20(np.linspace(0, 1, max(1, Nparticles))) #Color each particle
    scat = ax.scatter(snapshots[0], np.zeros(Nparticles), c = colors[:Nparticles], s = 35, zorder = 3)
    txt = ax.text(0.01, 0.95, "", transform=ax.transAxes, va="top")
    
    def update(frame):
        positions = snapshots[frame]
        pot = phase[frame]
        
        scat.set_offsets(np.column_stack((positions, np.zeros(len(positions)))))
        
        if pot == 0:
            ax.set_facecolor("#e8f1ff")
            pot_name = "V32"
        else:    
            ax.set_facecolor("#fff2e0")
            pot_name = "V31"
            
        txt.set_text(f"frame {frame}/{n_frames-1} | {pot_name}")
        return scat, txt
    
    ani = FuncAnimation(fig, update, frames=n_frames, interval=interval, blit=True)
    plt.close(fig)
    return ani

# %%
plot_walk_exclusion_sawtooth(Tp=40, width=4, Nx=20, Ns=4, Nc=5, alpha=0.2, beta = 1, k = 1000)

# %%
#Run this code to get animation, cant have in notebook without getting git overflow
""" ani = animate_random_walk_exclusion(Tp=40, width=4, Nx=20, Ns=4, Nc=5, alpha=0.2, beta=1, k=1000)
HTML(ani.to_jshtml()) """
# Out:
# ' ani = animate_random_walk_exclusion(Tp=40, width=4, Nx=20, Ns=4, Nc=5, alpha=0.2, beta=1, k=1000)\nHTML(ani.to_jshtml()) '

# %% [markdown]
# Animate_random_walk_exclusion funksjonen er i stor grad laget med AI, da vi ikke var veldig kjent med snapshot animering og de diverse funksjonene vi trengte for å oppdatere farger og bevegelse underveis.
#
# Vi ser at partiklene aldri krysser hverandre, og alltid har en avstand større en width, som stemmer med modellen. Det ser ut til at det er en drift mot høyre som vi diskuterte i oppgave 3, så dette stemmer også godt. I V32 er ca $p^- = p^+ = p^0 = \frac{1}{3}$ og bevegelsene ser tilfeldige ut, med noen kollisjoner. I V31 vil vi derimot få drift mot potensialminima. Noen partikler søker minima og kolliderer, imens andre med større frihet, spesielt mot endene, vil bevege seg til de når minima, og så stå stille til det konstante potensialet aktiveres.

# %% [markdown]
# ## Oppgave 4b\)

# %%
def plot_currenTparticle_exclusion_sawtooth(Tp: int, 
                                             width: int, 
                                             Ns: int, Nx: int, Nc: int, N_min: int, N_max: int, 
                                             alpha: float, k: float, beta: float, 
                                             h: float = 1) -> None:
    """Plot cycle-averaged current J_avg as function of particle density rho for the exclusion sawtooth model

    Args:
        Tp : Half-period of potential-switching
        width: Total width of particles
        Ns: Number of sawtooth periods
        Nx: Sites per sawtooth period
        Nc: Number of full cycles
        N_min: Minimum amount of particles. Should be at least 1 to avoid division-by-zero error
        N_max: Maximum amount of particles
        alpha: Position of potential switch within Nx, pos = Nxalpha
        k: Potential strength
        beta: Constant equal to 1/(Kb*T)
        h: Time-step size. Defaults to 1.

    Returns:
        None: Displays the plot
    """
    Np_arr = np.arange(N_min, N_max + 1)
    cycle_avg_J_arr = np.zeros(len(Np_arr))
    rho_arr = np.zeros(len(Np_arr))
    
    for i, Np in enumerate(Np_arr):
        rho = width * Np /(Ns * Nx)
        initial_grid = build_initial(width, 2, Nx, Ns, Np)
        
        grid, cycle_avg_J, positions_arr, snapshot, phase = random_walk_exclusion_sawtooth(initial_grid, Tp, width, Nx, Ns, Nc, alpha, k, beta, h, store_positions = False)
        
        cycle_avg_J_arr[i] = cycle_avg_J.mean()
        rho_arr[i] = rho
        
    fig, ax = plt.subplots(figsize = (8, 4))
    ax.plot(rho_arr, cycle_avg_J_arr)
    ax.set_title("Average current as function of particle density")
    ax.set_xlabel(r"$\rho$")
    ax.set_ylabel(r"$J_{avg}$")
    ax.grid()

    plt.show()
    
    return None

# %%
plot_currenTparticle_exclusion_sawtooth(Tp = 300, width = 20, Ns = 10, Nx = 100, Nc = 100, N_min = 1, N_max = 50, alpha = 0.2, k = 1000, beta = 1)

# %% [markdown]
# Når partikkeltettheten øker forventer vi flere kollisjoner og mindre drift av partikler, derfor burde $J_{avg}$ minke for høyere $\rho$, som også er reflektert i grafen. Med partikkeltetthet lik 1 kan det ikke skje noe bevegelse da griden er full.

# %% [markdown]
# ## Oppgave 4c\)

# %%
def plot_currenTperiod_exclusion_sawtooth(width: int, 
                                            Tp_min : int,
                                            Tp_max: int,
                                            Ns: int, Nx: int, 
                                            alpha: float, k: float, beta: float, 
                                            h: float = 1) -> None:
    """Plot cycle-averaged current J_avg as function of half period Tp for the exclusion sawtooth model

    Args:
        width: Total width of particles
        Tp_min: Minimum half period
        Tp_max: Maximum half period
        Ns: Number of sawtooth periods
        Nx: Sites per sawtooth period
        alpha: Position of potential switch within Nx, pos = Nxalpha
        k: Potential strength
        beta: Constant equal to 1/(Kb*T)
        h: Time-step size. Defaults to 1.

    Returns:
        None: Displays the plot
    """
    Tp_arr = np.arange(Tp_min, Tp_max + 1, 10)
    cycle_avg_J_arr = np.zeros(len(Tp_arr))
    
    for i, Tp in enumerate(Tp_arr):
        Nc = 30000//Tp #Nc*Tp = 30000
        initial_grid = build_initial(width, 2, Nx, Ns)
        
        grid, cycle_avg_J, positions_arr, snapshot, phase = random_walk_exclusion_sawtooth(initial_grid, Tp, width, Nx, Ns, Nc, alpha, k, beta, h, store_positions = False)
        
        cycle_avg_J_arr[i] = cycle_avg_J.mean()
    
    fig, ax = plt.subplots(figsize = (8, 4))
    ax.plot(Tp_arr, cycle_avg_J_arr)
    ax.set_title(r"Average current as function of half-period with $Tp N_c = 30 000$")
    ax.set_xlabel(r"$Tp$")
    ax.set_ylabel(r"$J_{avg}$")
    ax.grid()
    
    return None

# %%
plot_currenTperiod_exclusion_sawtooth(width = 20, Tp_min = 10, Tp_max = 300, Ns = 10, Nx = 100, alpha = 0.2, k = 1000, beta = 1)

# %% [markdown]
# Høyere $Tp$ gir lengre faser av hvert potensial. For høyere $Tp$ og dermed lengre faser rekker da systemet i større grad å nærme seg likevekt i de ikke-konstante potensial fasene, som gir mindre netto drift per syklus. Dette reflekteres også i plottet. Siden $Tp N_c$ holdes konstant vil også større $Tp$ bety færre sykluser, som burde øke usikkerheten, men dette ser vi ikke veldig tydelig.

# %% [markdown]
# ### Oppgave 4d)

# %% [markdown]
# Valgt vitenskapelig artikkel: https://arxiv.org/pdf/1410.4981
#
#
# #### Beskrivelse av modellen
#
# Artikkelen undersøker de stasjonære egenskapene til et system av interagerende partikler med hard core exclusion og hvordan de beveger seg i et diskret éndimensjonalt vekslende ratchet-potensial. Dette er tilsvarende det vi har undersøkt, men i tillegg ser artikkelen på effekten av et uordnet potensial, som blir gjort ved å bryte periodisiteten til sawtooth-potensialet.
#
# Systemet har to forskjellige tilstander, "ON" og "OFF". I OFF-tilstanden ($V=0$) diffunderer partiklene til naboposisjoner, hver tilstanden har i utgangspunktet lik sannsynlighet, men dette vil endres ved kollisjon. I ON-tilstanden hopper partiklene med overgangssannsynlighet (for tilstandsendring $n \rightarrow m$, der $m \in \{ n-1, n, n+1 \}$):
#
# $$P(n\rightarrow m) = r\cdot \min(1,\exp\left(\beta(V(n)-V(m))\right)), \hspace{5mm} r=1/\beta.$$
#
# De bruker en såkalt Metropolis-algoritme (https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm) hvor steg i retning av et lavere potensiale vil akspteres med sannsynlighet $r$ og et steg i retning av et større potensiale vil skaleres med Boltzmann-faktoren, men ikke normaliseres, hvilket gjør at partiklene diffunderer i større grad. Dette vil likevel i praksis gi kvalitativt lignende resultater, særlig blir likevektsfordelingen lik, men det er også noen forskjeller, hvilket skal diskuteres videre.
#
# I kapittel 2 i artikkelen undersøkes det hard-core-ekslusjon i et ratchet-potensial, men uten å gi partiklene en bredde. Imidlertid vil partikkeltettheten $\rho = N/(wL)$ aldri overstige 1, som vi i oppgave 4 sørger for ved å gi partikkelbredden $b$ en øvre grense $\rho_{\max} = 1$ gjennom $\rho = bNp/(N_s Nx)$.
#
# Modellen deres viser at man får en global strøm av partiklene som er tetthetsavhengig, i likhet med det vi fant. Dessuten skal vi i likhet med artikkelens modell anta at partikkelbredden er 1 når vi reproduserer Figur 2(b).
#
# Vi kan kan gjenskape Figur 2(b) i artikkelen som viser den gjennomsnittlige hastigheten til systemet av partikler i ratchet-potensialet. Den gjennomsnittlige hastigheten er proporsjonal til den gjennomsnittelige nettostrømmen av partikler, $J_{avg}$. Diffusjonskoeffesienten kan empirisk beregnes som
#
# $$D \approx \frac{\text{MSD}}{2Tp} = \frac{\left< (x-x_0)^2\right>}{2Tp} = \text{Var}\left[J_{avg}\right]Tp = \frac{1}{2} \text{Var}\left[J_{avg}\right]T_{cycle} \hspace{1mm};\hspace{5mm} T_{cycle} = 2Tp,$$
#
# der MSD er "Mean squared displacement" (https://en.wikipedia.org/wiki/Fick%27s_laws_of_diffusion).
#
#
# #### Hastighetsutvikling ved økende frekvens
#
# Chacko og Tripathy har i likhet med oss undersøkt gjennomsnittelig netto partikkeldrift, men har i tillegg beregnet gjennomsnittelig partikkelhastighet og diffusjonskonstanten, som det er mulig å se under.
#
#
# ##### Utsnitt av Figur 2(b)
# ![Figur 2(b)](artikkel_2.png)

# %% [markdown]
# Vi ser av Figur 2(b) at $v$ øker monotont med $\omega$ og flater ut ved høye frekvenser, asymptotisk mot en maksimumsverdi. D på sin side har et maksimum ved mellomliggende frekvenser og faller av på begge sider. For $a=1$ er hastigheten høyere enn for $a=2$ ved alle frekvenser, som kan forklares med at det da blir større asymmetri i potensialet, og følgelig mindre partikkeldrift.

# %% [markdown]
# #### Sammenligning og gjenskaping av resultatet

# %% [markdown]
# Vi skal nå prøve å forstå resultatet i Figur(2b). For å gjøre dette, skal vi prøve å gjenskape resultatet ved å justerer parametrene og modellen vår. Vi ser hovedsaklig på forskjellen ved bruk av en Boltzmann-modell og en Metropolis-modell, og forskjellen på interagerende og ikke-interagerende partikler i hver modell.

# %%
# Implement the Metropolis-algorithm like in the article
# This is mainly redefining of already implemented functions 

@njit
def probs_metropolis(beta: float, x: int, Nx: int, alpha: float, k: float, t: int, Tp: int) -> tuple[float, float]:
    """Calculate move probabilities using Metropolis rates where r = 1/beta.
    Args:
        beta: Constant equal to 1/(kb*T)
        x: Position on x axis
        Nx: Length of interval for periodic potential
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Constant for potential strength
        t: Timestep within [0, 2*Tp]
        Tp: Time period between potential switches
    Returns:
        p_minus, p_plus: Probabilities for a move to the left (minus) and right (plus)
    """
    r = 1.0 / beta  

    V0  = periodic_pot(t, Tp, x, Nx, alpha, k, beta)
    Vm  = periodic_pot(t, Tp, x - 1, Nx, alpha, k, beta)
    Vp  = periodic_pot(t, Tp, x + 1, Nx, alpha, k, beta)

    exp_plus  = beta * (Vp - V0)  
    exp_minus = beta * (Vm - V0)  

    if exp_plus <= 0:
        p_plus = r
    else:
        p_plus = r * np.exp(-exp_plus)

    if exp_minus <= 0:
        p_minus = r
    else:
        p_minus = r * np.exp(-exp_minus)

    return p_minus, p_plus


@njit
def random_walk_exclusion_sawtooth_m(initial_grid: np.ndarray, 
                                   Tp: int, 
                                   width: int, 
                                   Nx: int, Ns: int, Nc: int,
                                   alpha: float, k: float, beta: float,
                                   h: int, store_positions:bool = True) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    """Simulates random walk with exclusion in rachet potential with Metropolis-rates

    Args:
        initial_grid: Initial distribution of particles (0/1)
        Tp : Half-period of potential-switching
        width: Total width of particles
        Nx: Sites per sawtooth period
        Ns: Number of sawtooth periods
        Nc: Number of full cycles
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Potential strength
        beta: Constant equal to 1/(Kb*T)
        h: Time-step size
        store_positions: Defaults to True. If True, store particle positions for each time step
        store_anim: Defaults to False. If True, store snapshots of positions and phaase_arr with potential for each time_step. 

    Returns:
        occupancy: Array(True/False) describing particle locations in final grid
        cycle_avg_J: Cycle-averaged current 
        positions_arr: Stores positions (T, Np) for each time step if enabled, else (1,1) zero-array
        snapshots: Stores positions (n_frames, Np) for each frame and particle if enabled, else (1, 1) zero-array
        phase: Stores active potential (n_frames) for each frame if enabled, else (1) zerro_array
    """
    T = 2*Nc*Tp
    occupancy = initial_grid.astype(np.bool_)
    positions = np.where(occupancy)[0].copy()
    Np = len(positions)
    if store_positions:
        positions_arr = np.zeros((T, Np), dtype=np.int64)
    else:
        positions_arr = np.zeros((1, 1), dtype=np.int64)
    
    
    snapshots = np.zeros((1, 1), dtype=np.int64)
    phase = np.zeros(1, dtype=np.int64)  
    J_arr = np.zeros(T)
    order = np.arange(Np)
    
    for t in range(0, T, h):
        nplus = 0
        nminus = 0
        np.random.shuffle(order)
        
        for n in range(Np):
            idx = order[n]
            i = positions[idx]
            
            p_minus, p_plus = probs_metropolis(beta, i, Nx, alpha, k , t, Tp)
            
            step = walk_dir(p_minus, p_plus)
            new_i = (i + step)%(Ns*Nx)

            check_left = np.arange(new_i - width + 1, new_i +1)%len(occupancy)
            check_right = np.arange(new_i , new_i + width)%len(occupancy)
            
            if new_i == (i + 1) % (Ns*Nx) and occupancy[check_right].any():
                continue
            elif new_i == (i - 1) % (Ns*Nx) and occupancy[check_left].any():
                continue
            
            occupancy[i] = False
            occupancy[new_i] = True
            positions[idx] = new_i
            
            if new_i == (i + 1) % (Ns*Nx): 
                nplus += 1
            elif new_i == (i - 1) % (Ns*Nx): 
                nminus += 1
            
        J_arr[t] = (nplus - nminus)/Np
        if store_positions:
            positions_arr[t] = positions
            
    n_cycles = len(J_arr)//(2*Tp)       
    J_reshaped = J_arr.reshape(n_cycles, 2*Tp)
    cycle_avg_J = np.zeros(n_cycles)
    
    for c in range(n_cycles):
        cycle_avg_J[c] = J_reshaped[c].mean()
        
    return occupancy.astype(np.int64), cycle_avg_J, positions_arr, snapshots, phase

# %%
@njit
def compute_velocity_diffusion_omega(omega_arr : np.ndarray, random_walk_fun, Np: int, width: int, Nx: int, Ns: int, alpha: float, k: float, beta: float , Nc: int =20) -> tuple[np.ndarray, np.ndarray]:
    """Computes mean particle velocity and diffusion coefficient for each frequency omega.
    Args:
        omega_arr: Array of frequencies omega = 1/(2*Tp)
        random_walk_fun: Random walk function
        Np: Number of particles
        width: Particle width
        Nx: Sites per sawtooth period
        Ns: Number of sawtooth periods
        alpha: Position of potential switch within Nx, pos = Nx*alpha
        k: Potential strength
        beta: Constant equal to 1/(Kb*T)
        Nc: Number of full cycles per simulation. Defaults to 20
    Returns:
        v_arr: Array of mean particle velocities for each omega value
        D_arr: Array of diffusion coefficients for each omega value
    """
    v_arr = np.zeros(len(omega_arr))
    D_arr = np.zeros(len(omega_arr))

    for i, omega in enumerate(omega_arr):
        Tp = int(1 / (2 * omega))
        if Tp < 1:
            continue

        initial_grid = build_initial(width, 2, Nx, Ns, Np)
        grid, cycle_avg_J, positions_arr, snapshot, phase = random_walk_fun(initial_grid, Tp, width=width, Nx=Nx, Ns=Ns, Nc=Nc, alpha=alpha, k=k, beta=beta, h=1, store_positions=False)

        T_cycle = 2 * Tp
        v_arr[i] = cycle_avg_J.mean()
        D_arr[i] = (np.var(cycle_avg_J) * T_cycle) / 2

    return v_arr, D_arr


def plot_velocity_diffusion_omega(omega_arr: np.ndarray, v1_arr: np.ndarray, D1_arr: np.ndarray, v2_arr: np.ndarray, D2_arr:np.ndarray, a: float, metropolis: bool) -> None:
    """Plots mean particle velocity and diffusion coefficient as functions of frequency omega.
    Args:
        omega_arr: Array of frequencies omega = 1/(2*Tp)
        v1_arr: Array of mean particle velocities with interacting particles
        D1_arr: Array of diffusion coefficients with interacting particles
        v2_arr: Array of mean particle velocities with non-interacting particles
        D2_arr: Array of diffusion coefficients with non-interacting particles
        a: Sawtooth length parameter
        metropolis: Wether the computations uses metropolis rates or not
    Returns:
        None: Displays the plot
    """
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))

    v_title = "Mean particle velocity as function of frequency " + f"\n[a = {a}]"
    w1_title = "Diffusion coefficient for interacting particles " + f"\n[a = {a}]"
    w2_title = "Diffusion coefficient for non-interacting particles " + f"\n[a = {a}]"

    if metropolis:
        v_title += " (Metropolis rates)"
        w1_title += " (Metropolis rates)"
        w2_title += " (Metropolis rates)"


    ax1.plot(omega_arr, v1_arr, 'o-', color='orange', label='Interacting particles')
    ax1.plot(omega_arr, v2_arr, 'o-', color='royalblue', label='Non-interacting particles')
    ax1.set_xlabel(r"$\omega$")
    ax1.set_ylabel(r"$v$")
    ax1.set_title(v_title)
    ax1.set_xscale("log")
    ax1.grid()
    ax1.legend()

    ax2.plot(omega_arr, D1_arr, 'o-', color='orange', label='Interacting particles')
    ax2.set_xlabel(r"$\omega$")
    ax2.set_ylabel(r"$D$")
    ax2.set_title(w1_title)
    ax2.set_xscale("log")
    ax2.grid()

    ax3.plot(omega_arr, D2_arr, 'o-', color='royalblue', label='Non-interacting particles')
    ax3.set_xlabel(r"$\omega$")
    ax3.set_ylabel(r"$D$")
    ax3.set_title(w2_title)
    ax3.set_xscale("log")
    ax3.grid()

    plt.tight_layout()
    plt.show()
    
    return None

# %% [markdown]
# #### Overgangssannsynlighet med Boltzmannsstatistikk

# %%
# Parameters as in the article
a1 = 1
a2 = 2
w = 6
alpha1 = a1/w
alpha2 = a2/w

omega_arr = np.logspace(-3, np.log10(0.5), 40)

# Interacting particles (with a=1)
v11_arr, D11_arr = compute_velocity_diffusion_omega(
omega_arr, random_walk_exclusion_sawtooth, Np=25, width=1, Nx=6, Ns=50,
    alpha=alpha1, k=5.0, beta=2.0, Nc=500
)

# Non-interacting particles (with a=1)
v12_arr, D12_arr = compute_velocity_diffusion_omega(
omega_arr, random_walk_exclusion_sawtooth, Np=1, width=1, Nx=6, Ns=50,
    alpha=alpha1, k=5.0, beta=2.0, Nc=500
)

# Interacting particles (with a=2)
v21_arr, D21_arr = compute_velocity_diffusion_omega(
omega_arr, random_walk_exclusion_sawtooth, Np=25, width=1, Nx=6, Ns=50,
    alpha=alpha2, k=5.0, beta=2.0, Nc=500
)

# Non-interacting particles (with a=2)
v22_arr, D22_arr = compute_velocity_diffusion_omega(
omega_arr, random_walk_exclusion_sawtooth, Np=1, width=1, Nx=6, Ns=50,
    alpha=alpha2, k=5.0, beta=2.0, Nc=500
)


plot_velocity_diffusion_omega(omega_arr, v11_arr, D11_arr, v12_arr, D12_arr, a1, metropolis=False)
plot_velocity_diffusion_omega(omega_arr, v21_arr, D21_arr, v22_arr, D22_arr, a2, metropolis=False)

# %% [markdown]
# #### Overgangssannsynlighet med Metropolis-rater

# %%
# Parameters as in the article
a1 = 1
a2 = 2
w = 6
alpha1 = a1/w
alpha2 = a2/w

omega_arr = np.logspace(-3, np.log10(0.5), 40)

# Interacting particles (with a=1)
v11_arr, D11_arr = compute_velocity_diffusion_omega(
omega_arr, random_walk_exclusion_sawtooth, Np=25, width=1, Nx=6, Ns=50,
    alpha=alpha1, k=5.0, beta=2.0, Nc=500
)

# Non-interacting particles (with a=1)
v12_arr, D12_arr = compute_velocity_diffusion_omega(
omega_arr, random_walk_exclusion_sawtooth, Np=1, width=1, Nx=6, Ns=50,
    alpha=alpha1, k=5.0, beta=2.0, Nc=500
)

# Interacting particles (with a=2)
v21_arr, D21_arr = compute_velocity_diffusion_omega(
omega_arr, random_walk_exclusion_sawtooth, Np=25, width=1, Nx=6, Ns=50,
    alpha=alpha2, k=5.0, beta=2.0, Nc=500
)

# Non-interacting particles (with a=2)
v22_arr, D22_arr = compute_velocity_diffusion_omega(
omega_arr, random_walk_exclusion_sawtooth, Np=1, width=1, Nx=6, Ns=50,
    alpha=alpha2, k=5.0, beta=2.0, Nc=500
)


plot_velocity_diffusion_omega(omega_arr, v11_arr, D11_arr, v12_arr, D12_arr, a1, metropolis=True)
plot_velocity_diffusion_omega(omega_arr, v21_arr, D21_arr, v22_arr, D22_arr, a2, metropolis=True)

# %% [markdown]
# Disse simuleringene reproduserer den kvalitative trenden i $v(\omega)$, men de kvantitative verdiene avviker fordi vi bruker en Boltzmann-modell istedenfor Metropolis-modellen. Sistnevnte gir høyere diffusjon og dermed høyere $v$ ved høye $\omega$, som er i bedre overenstemmelse med artikkelen.
#
# En kan forklare dette ved at for lave $\omega$ vil partiklene ligge i potensialminimumene i ON-tilstanden, og sprer seg deretter symmetrisk i OFF-tilstanden. Netto forflytning per syklus er liten fordi systemet er nær likevekt. For større $\omega$ vil gjennomsnittlige hastighet øke da forflytningen blir større på kortere tid da potensialet veksler fortere og følgelig vil strømmen av partikler bli større, men for tilstrekkelig store verdier vil det partiklene i liten grad nå likevekt og vil heller ikke diffundere noe særlig på grunn av periodens korthet.

# %% [markdown]
# #### Sammenligning av våre og artikkelens resultater
#
#
# Når vi bruker Metropolis-rater finner vi kvalitativt samme utvikling i hastighet ved økende frekvens $\omega$. Valget av Metropolis-algoritme er sentral for å forklare resultatene i artikkelen. En grunnleggende forskjell mellom denne algoritmen og Boltzmann-modellen er at partiklene diffundere i større grad med Metropolis-algoritmen, og hastigheten forblir stor lenger med økende $\omega$ enn Boltzmann-modellen. Med Metropolis-rater er resultatene i Figur 2(b), og for øvrig i artikkelen, i overenstemmelse med våre simuleringer.
#
#
# For hver modell diffunderer partiklene i vesentlig større grad når de ikke interagerer med hverandre, hvilket gir mening, og partiklene har kvalitativt lik gjennomsnittsfart som kan forklares med at den globale partikkeldriften fremdeles er lik såfremt det er en potensialforskjell. Hard-core-eksklusjon reduserer imidlertid den effektive hastigheten ved høy tetthet, fordi partiklene vil blokkere hverandre.
#
# I tillegg får vi kvalitativt likt resultat for når vi endrer lengde-parameteren $a$ for $a=1,2$. For $a=2$ er det større asymmetri og mindre drift, og større drift (mot høyre) for $a=1$.

# %% [markdown]
# Oppgave 4d
#
# Den ene figuren vi skulle gjennskape er den over, men vi har i tillegg gjort det som en annen figur. Det står jo i oppgave 4d at vi bare skal ta utgangspunkt i en figur, så hvis dere som retter bare skal se på gjennskaping av 1 graf, og ikke er interessert i en annen sammenlikning, kan dere bare ignorere oppgaven skrevet under:
#
# I artikkelen plotter de partikkelstrøm på Y aksen og tetthet på x aksen, slik som vi gjorde i oppgave 4b. Vi har tenkt å prøve å tilpasse koden våres, for å se om den kan gi samme resultat som forsknngsartikkelen.
#
# Derfor lagde vi en funksjonen current_density_graph_4d som tar inn det samme som plot_current_particle_exclusion_sawtooth, med noen forandringer. Vi lar partikklene nå en steady state, noe som de også gjør i partikkelen. Dette tar vi hensyn til ved å bare bruke de siste 40% av current verdiene i cycle_avg_J når vi rekner ut gjennomsnittlig strøm.
#
# I tillegg må vi forandre på startparameterne for å få dem til å matche forskningsartikkelparameterne. Hvis man ser på intutverier vi har lagt inn i current_density_graph_4d kan man se hvilke forskningsparametre som ble brukt. Etter å ha gjort dette, kjører vi programmet, og bruker regresjon for å finne beste polynom på formen beskrevet i forskningsartikkelen. på formen man kan se i regresjonsfunksjonen. Jeg har ikke økt antall sykluser til å matche forskningsartikkelen. Der kjører de veldig mange simulasjoner, men dette tar alt for lang tid i våres program. Dette er kanskje den største feilskilden. I tillegg har vi ikke brukt metropolisrater, så dette kan også skape litt andre resultater.
#
# Ut fra resultatene printet helt nederst under plottene ser ci at vi får resultater som likner mye på forskningsartikkelen. Vi får bare noen få prosent avvik for A0 og A1. I tillegg, der vi sammenlikner plottet i forskningsartikkelen og våres plott, ser man at de har samme form. De likner mye. Dette indikerer at programmet våres fungerer likt som det i forskningsartikkelen.

# %%
def current_density_steady_state(Tp: int, 
                                width: int, 
                                Ns: int, Nx: int, Nc: int, N_min: int, N_max: int, 
                                alpha: float, k: float, beta: float,
                                h: float = 1) -> tuple[np.ndarray, np.ndarray]:
    """Plot cycle-averaged current J_avg as function of particle density rho for the exclusion sawtooth model

    Args:
        Tp : Half-period of potential-switching
        width: Total width of particles
        Ns: Number of sawtooth periods
        Nx: Sites per sawtooth period
        Nc: Number of full cycles
        N_min: Minimum amount of particles. Should be at least 1 to avoid division-by-zero error
        N_max: Maximum amount of particles
        alpha: Potential physical parameter
        k: Potential physical parameter
        beta: Physical parameter
        h: Time-step size. Defaults to 1.

    Returns:
        tuple: Returns tuple of Current array, density array
    """
    Np_arr = np.arange(N_min, N_max + 1)
    cycle_avg_J_arr = np.zeros(len(Np_arr))
    rho_arr = np.zeros(len(Np_arr))
    
    for i, Np in enumerate(Np_arr):
        rho = width * Np /(Ns * Nx)
        initial_grid = build_initial(width, 2, Nx, Ns, Np)
        
        grid, cycle_avg_J, positions_arr, *_ = random_walk_exclusion_sawtooth(initial_grid, Tp, width, Nx, Ns, Nc, alpha, k, beta, h, store_positions = False)
        
        velocity_steady_state = cycle_avg_J[3 * (len(cycle_avg_J) // 5):].mean()
        cycle_avg_J_arr[i] = rho * velocity_steady_state
        rho_arr[i] = rho
        
    return rho_arr, cycle_avg_J_arr


def regression(p, A0, A1):
    return A0*p*(1-p) + A1*p**2*(1-p)**2

#Verdier fra forskningsartikkel
omega = 0.05
Ns = 50
Nx = 6

rho_arr, cycle_avg_J_arr = current_density_steady_state(Tp = int(1/(2*omega)), width = 1, Ns = 50, Nx = 6, Nc = 300, N_min = 1, N_max = Ns*Nx - 1, alpha = 1/6, k = 2.5, beta = 2.0)
(A0, A1), _ = curve_fit(regression, rho_arr, cycle_avg_J_arr)


x = np.linspace(0, 1, 200)
y = regression(x, A0, A1)
x_forskning = np.linspace(0, 1, 200)
y_forskning = regression(x_forskning,0.0393,-0.01530  ) 

fig, ax = plt.subplots(1, 2, figsize=(12,5))


ax[0].plot(x, y, label="Regression polynom")
ax[0].plot(rho_arr, cycle_avg_J_arr, label="Numerical calculation")

ax[0].set_title("Our regression")
ax[0].set_xlabel("rho")
ax[0].set_ylabel("J")
ax[0].legend()

ax[1].plot(rho_arr, cycle_avg_J_arr, label="Our numerical calculation")
ax[1].plot(x_forskning, y_forskning, label="Regression from paper")

ax[1].set_title("Compare result with article")
ax[1].set_xlabel("rho")
ax[1].set_ylabel("J")
ax[1].legend()

plt.tight_layout()
plt.show()

#Sammenlikning av data: 
print("Research paper results:  A0 = "  + str(0.0393) + ", A1 = " + str(-0.01530))
print("Regression value for parameters: A0 = " + str(A0) + ", A1 = " + str(A1))
print("Relative error: A0_error = " + str(abs(100*((A0-0.0393)/A0) ))+ ", A1_error = " + str(abs((A1-(-0.01530))/A1)))
# Out:
# Research paper results:  A0 = 0.0393, A1 = -0.0153
# Regression value for parameters: A0 = 0.03881056655308618, A1 = -0.004466256389026901
# Relative error: A0_error = 1.2610829739997795, A1_error = 2.4256877947245505
